# %% [markdown]
# # 13 EDA Report

# %% [markdown]
# ## Dataset Overview

# %% [markdown]
# ## Step 1 – Understand the Concept (Markdown)
# Dataset Overview – Definition; A Dataset Overview is the first step of Exploratory Data Analysis (EDA). It helps us understand the basic information about the dataset before performing detailed analysis.
#
# It includes the source of the dataset, number of rows and columns, input features, target variable, and the business domain.
#
# ## Step 2 – Demonstrate the Concept (Markdown)
# Dataset Overview
# 1. Dataset Source
#
# The dataset used for this project is the house_price_prediction_cleaned.xls file provided for the House Price Prediction project.
#
# 2. Dataset Size
#
# The dataset contains:
#
# 50 rows/records
# 12 columns
# 11 input features
# 1 target variable
#
# Therefore, the dataset size is 50 × 12.
#
# 3. Features
#
# The features used to predict house prices are:
#
# Numerical Features:
#
# House_ ID
# Area_sqft
# Bedrooms
# Bathrooms
# Age_years
# Location_Score
# Parking_Spaces
#
# Categorical Features:
#
# Property_Type
# Furnishing_Status
# Construction_Status
# Locality_Type
# 4. Target
#
# The target variable is:
#
# Price_lakhs
#
# It represents the price of the house in lakhs.
#
# 5. Domain
#
# The dataset belongs to the Real Estate domain.
#
# The objective is to predict the price of a house based on its characteristics such as area, number of bedrooms, bathrooms, age, location score, property type, furnishing status, and locality.

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("house_price_prediction_cleaned.csv")

# %%
# Dataset size
print("Dataset Size:", df.shape)
# Out:
# Dataset Size: (50, 12)

# %%
# Column names
print("\nFeatures/Columns:")
print(df.columns.tolist())
# Out:
# nFeatures/Columns:
# ['House_ ID', 'Area_sqft', 'Bedrooms', 'Bathrooms', 'Age_years', 'Location_Score', 'Parking_Spaces', 'Price_lakhs', 'Property_Type', 'Furnishing_Status', 'Construction_Status', 'Locality_Type']

# %%
# Dataset information
print("\nDataset Information:")
df.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   House_ ID            50 non-null     int64
#  1   Area_sqft            50 non-null     float64
#  2   Bedrooms             50 non-null     float64
#  3   Bathrooms            50 non-null     float64
#  4   Age_years            50 non-null     float64
#  5   Location_Score       50 non-null     float64
#  6   Parking_Spaces       50 non-null     float64
#  7   Price_lakhs          50 non-null     float64
#  8   Property_Type        50 non-null     object
#  9   Furnishing_Status    50 non-null     object
#  10  Construction_Status  50 non-null     object
#  11  Locality_Type        50 non-null     object
# dtypes: float64(7), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
# Target variable
target = "Price_lakhs"

print("\nTarget Variable:", target)
# Out:
# Target Variable: Price_lakhs

# %%
# Numerical columns

Numerical_features = df.select_dtypes(include = "number").columns.tolist()

print("Numerical columns:",Numerical_features)


Categorical_columns = df.select_dtypes(include = object).columns.tolist()

print("Categorical columns:", Categorical_columns )
# Out:
# Numerical columns: ['House_ ID', 'Area_sqft', 'Bedrooms', 'Bathrooms', 'Age_years', 'Location_Score', 'Parking_Spaces', 'Price_lakhs']
# Categorical columns: ['Property_Type', 'Furnishing_Status', 'Construction_Status', 'Locality_Type']

# %% [markdown]
# ### Data Quality

# %%
import pandas as pd
import numpy as np
df.head()
# Out:
#    House_ ID  Area_sqft  Bedrooms  Bathrooms  Age_years  Location_Score  \
# 0          1      850.0       4.0        1.0       20.5             5.0
# 1          2      900.0       2.0        1.0       18.0             5.0
# 2          3     2150.0       2.0        1.0       15.0             6.0
# 3          4     1000.9       2.0        2.0       12.0             6.0
# 4          5     1050.0       2.0        2.0       10.0             6.0
#
#    Parking_Spaces  Price_lakhs      Property_Type Furnishing_Status  \
# 0             1.0         42.0          Apartment       Unfurnished
# 1             2.0         45.0  Independent House    Semi-Furnished
# 2             1.0         48.0              Villa   Fully Furnished
# 3             1.0         52.0          Apartment    Semi-Furnished
# 4             1.0         55.0  Independent House       Unfurnished
#
#   Construction_Status Locality_Type
# 0       Ready to Move         Urban
# 1  Under Construction      Suburban
# ...

# %%
#Duplicates
duplicate_count = df.duplicated().sum()

duplicate_count
# Out:
# np.int64(0)

# %%
# missin values
missing_values = df.isnull().sum().sum()

missing_values
# Out:
# np.int64(0)

# %%
# Invalid values
numeric_columns = df.select_dtypes(include=np.number).columns
negative_values = (df[numeric_columns] < 0).sum()
negative_values
# Out:
# House_ ID         0
# Area_sqft         0
# Bedrooms          0
# Bathrooms         0
# Age_years         0
# Location_Score    0
# Parking_Spaces    0
# Price_lakhs       0
# dtype: int64

# %%
#Check Data Types

print(df.dtypes)
# Out:
# House_ ID                int64
# Area_sqft              float64
# Bedrooms               float64
# Bathrooms              float64
# Age_years              float64
# Location_Score         float64
# Parking_Spaces         float64
# Price_lakhs            float64
# Property_Type           object
# Furnishing_Status       object
# Construction_Status     object
# Locality_Type           object
# dtype: object

# %% [markdown]
# ### Statistical Findings

# %%
numeric_columns = df.select_dtypes(include=np.number).columns

print("Mean:")
print(df[numeric_columns].mean())

print("\nMedian:")
print(df[numeric_columns].median())

print("\nMode:")
print(df[numeric_columns].mode().iloc[0])
# Out:
# Mean:
# House_ ID           25.500
# Area_sqft         2120.028
# Bedrooms             3.580
# Bathrooms            2.800
# Age_years            6.450
# Location_Score       8.260
# Parking_Spaces       1.980
# Price_lakhs        137.500
# dtype: float64
#
# Median:
# House_ ID           25.5
# Area_sqft         2125.0
# Bedrooms             4.0
# Bathrooms            3.0
# Age_years            6.0
# Location_Score       8.0
# Parking_Spaces       2.0
# Price_lakhs        125.0
# dtype: float64
#
# Mode:
# House_ ID            1.0
# Area_sqft         2150.0
# Bedrooms             4.0
# Bathrooms            3.0
# Age_years            5.0
# Location_Score       8.0
# Parking_Spaces       2.0
# Price_lakhs         72.0
# Name: 0, dtype: float64

# %%
# Calculate Dispersion

print("Standard Deviation:")
print(df[numeric_columns].std())

print("\nVariance:")
print(df[numeric_columns].var())

print("\nRange:")
print(df[numeric_columns].max() - df[numeric_columns].min())
# Out:
# Standard Deviation:
# House_ ID          14.577380
# Area_sqft         746.310859
# Bedrooms            0.784805
# Bathrooms           0.782461
# Age_years           4.309754
# Location_Score      1.411469
# Parking_Spaces      0.514682
# Price_lakhs        76.329910
# dtype: float64
#
# Variance:
# House_ ID            212.500000
# Area_sqft         556979.898384
# Bedrooms               0.615918
# Bathrooms              0.612245
# Age_years             18.573980
# Location_Score         1.992245
# Parking_Spaces         0.264898
# Price_lakhs         5826.255102
# dtype: float64
#
# Range:
# House_ ID           49.0
# Area_sqft         2750.0
# Bedrooms             3.0
# Bathrooms            3.0
# Age_years           19.5
# Location_Score       5.0
# Parking_Spaces       2.0
# Price_lakhs        313.0
# dtype: float64

# %%
# Quartiles and IQR

Q1 = df[numeric_columns].quantile(0.25)
Q3 = df[numeric_columns].quantile(0.75)

IQR = Q3 - Q1

print("Q1:")
print(Q1)

print("\nQ3:")
print(Q3)

print("\nIQR:")
print(IQR)
# Out:
# Q1:
# House_ ID           13.25
# Area_sqft         1512.50
# Bedrooms             3.00
# Bathrooms            2.00
# Age_years            3.25
# Location_Score       7.25
# Parking_Spaces       2.00
# Price_lakhs         76.50
# Name: 0.25, dtype: float64
#
# Q3:
# House_ ID           37.75
# Area_sqft         2687.50
# Bedrooms             4.00
# Bathrooms            3.00
# Age_years            8.00
# Location_Score       9.00
# Parking_Spaces       2.00
# Price_lakhs        176.00
# Name: 0.75, dtype: float64
#
# IQR:
# House_ ID           24.50
# Area_sqft         1175.00
# Bedrooms             1.00
# Bathrooms            1.00
# Age_years            4.75
# Location_Score       1.75
# Parking_Spaces       0.00
# Price_lakhs         99.50
# dtype: float64

# %% [markdown]
# ### Detect Outliers Using IQR

# %%
for column in numeric_columns:

    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[
        (df[column] < lower_bound) |
        (df[column] > upper_bound)
    ]

    print(f"\n{column}")
    print("Lower Bound:", lower_bound)
    print("Upper Bound:", upper_bound)
    print("Number of Outliers:", len(outliers))
# Out:
# House_ ID
# Lower Bound: -23.5
# Upper Bound: 74.5
# Number of Outliers: 0
#
# Area_sqft
# Lower Bound: -250.0
# Upper Bound: 4450.0
# Number of Outliers: 0
#
# Bedrooms
# Lower Bound: 1.5
# Upper Bound: 5.5
# Number of Outliers: 0
#
# Bathrooms
# Lower Bound: 0.5
# Upper Bound: 4.5
# Number of Outliers: 0
#
# Age_years
# Lower Bound: -3.875
# Upper Bound: 15.125
# Number of Outliers: 2
#
# Location_Score
# Lower Bound: 4.625
# Upper Bound: 11.625
# Number of Outliers: 0
#
# Parking_Spaces
# Lower Bound: 2.0
# Upper Bound: 2.0
# Number of Outliers: 13
#
# Price_lakhs
# Lower Bound: -72.75
# Upper Bound: 325.25
# Number of Outliers: 2

# %% [markdown]
# ### Relationship Findings

# %%
#Correlations

correlation_matrix = df[numeric_columns].corr()

correlation_matrix
# Out:
#                 House_ ID  Area_sqft  Bedrooms  Bathrooms  Age_years  \
# House_ ID        1.000000   0.970901  0.823255   0.896395  -0.443490
# Area_sqft        0.970901   1.000000  0.784635   0.843954  -0.390025
# Bedrooms         0.823255   0.784635  1.000000   0.724496  -0.317075
# Bathrooms        0.896395   0.843954  0.724496   1.000000  -0.626367
# Age_years       -0.443490  -0.390025 -0.317075  -0.626367   1.000000
# Location_Score   0.726542   0.685594  0.598025   0.787190  -0.853320
# Parking_Spaces   0.738508   0.715597  0.585075   0.750004  -0.469686
# Price_lakhs      0.912396   0.917623  0.801792   0.825550  -0.459933
#
#                 Location_Score  Parking_Spaces  Price_lakhs
# House_ ID             0.726542        0.738508     0.912396
# Area_sqft             0.685594        0.715597     0.917623
# Bedrooms              0.598025        0.585075     0.801792
# Bathrooms             0.787190        0.750004     0.825550
# ...

# %%
target_correlation = correlation_matrix["Price_lakhs"].sort_values(
    ascending=False
)

print(target_correlation)
# Out:
# Price_lakhs       1.000000
# Area_sqft         0.917623
# House_ ID         0.912396
# Bathrooms         0.825550
# Bedrooms          0.801792
# Parking_Spaces    0.735845
# Location_Score    0.698695
# Age_years        -0.459933
# Name: Price_lakhs, dtype: float64

# %%
#Area vs Price
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(8, 5))


sns.scatterplot(
    data=df,
    x="Area_sqft",
    y="Price_lakhs"
)


plt.title("Area vs Price")
plt.xlabel("Area (sqft)")
plt.ylabel("Price (Lakhs)")
plt.show()

# %%
#Bedrooms vs Area
plt.figure(figsize=(8, 5))


sns.scatterplot(
    data=df,
    x="Bedrooms",
    y="Area_sqft"
)


plt.title("Bedrooms vs Area")
plt.xlabel("Bedrooms")
plt.ylabel("Area (sqft)")
plt.show()

# %% [markdown]
# ### Potential Data Problems

# %%
| Issue                    | Status                    | Action Required                     |
| ------------------------ | ------------------------- | ----------------------------------- |
| Missing values           | No missing values         | No treatment required               |
| Duplicate records        | No duplicates             | No treatment required               |
| Invalid numerical values | None obvious              | Continue validation                 |
| Outliers                 | Some potential outliers   | Investigate before treatment        |
| Categorical features     | Present                   | Encode before ML                    |
| Count variables          | Stored as float           | Convert to integer if appropriate   |
| Column name              | `House_ ID` has space     | Rename to `House_ID`                |
| Numerical scaling        | Different ranges          | Consider scaling                    |
| Skewness                 | Price may be right-skewed | Consider transformation if required |
| File format              | `.xls` but CSV content    | Save with correct format            |

# %% [raw]
# Final EDA Conclusion
#
# The dataset is generally clean and suitable for machine learning. There are no missing values or duplicate records. The main preprocessing tasks are categorical encoding, appropriate data-type correction, investigation of potential outliers, and consideration of feature scaling/transformation. Feature engineering can be explored after the basic preprocessing is completed.

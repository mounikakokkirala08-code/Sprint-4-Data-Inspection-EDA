# %% [markdown]
# ## 1. Number of Rows

# %% [markdown]
# ### Step 1 – Understand the Concept (Markdown)
#
# In my own words: The number of rows tells us how many records or observations are present in a DataFrame.
#
# Definition: Rows represent individual records in a dataset.
#
# ### Step 2 – Demonstrate the Concept (Markdown)
#
# Real-world analogy: If a student dataset contains 100 students, it has 100 rows.
#
# ### Step 3 – Implement the Concept (Python)

# %%
import pandas as pd
data = pd.read_csv("house_price_prediction_50_rows_categorical_datetime.csv")

print(len(data))
# rows
# Out:
# 52

# %% [markdown]
# ### 2. Number of Columns
# Step 1 – Understand the Concept (Markdown)
#
# In my own words: The number of columns tells us how many variables or features are present.
#
# Definition: Columns represent variables/features in a DataFrame.
#
# ### Step 2 – Demonstrate the Concept (Markdown)
#
# Real-world analogy:
# If we have Name, Age, and Marks, there are 3 columns.
#
# ### Step 3 – Implement the Concept (Python)
#  Get the number of columns

# %%
print(len(data.columns))
# columns
# Out:
# 14

# %% [markdown]
# ## 3. Data Types

# %% [markdown]
# ### Step 1 – Understand the Concept (Markdown)
#
# In my own words: Data types tell us what kind of data each column contains.
#
# Definition: Data types specify whether a column contains integers, floats, strings, dates, etc.
#
# ### Step 2 – Demonstrate the Concept (Markdown)
#
# For example:
#
# Age → integer
# Marks → integer
# Name → string/object
# ### Step 3 – Implement the Concept (Python)
#  Display data types of all columns

# %%
print(data.dtypes)
# Out:
# House_ ID                int64
# Area_sqft              float64
# Bedrooms               float64
# Bathrooms                int64
# Age_years              float64
# Location_Score          object
# Parking_Spaces         float64
# Price_lakhs              int64
# Property_Type           object
# Furnishing_Status       object
# Construction_Status     object
# Locality_Type           object
# Listing_Date            object
# Listing_Time            object
# dtype: object

# %% [markdown]
# ### 4. Column Names

# %% [markdown]
# ### Step 1 – Understand the Concept (Markdown)
#
# In my own words: Column names identify the variables in a DataFrame.
#
# Definition; Column names are labels assigned to each column.
#
# ### Step 2 – Demonstrate the Concept (Markdown)
#
# For example; Name, Age, Marks
#
# ### Step 3 – Implement the Concept (Python)
#  Display all column names

# %%
print(data.columns)
# Out:
# Index(['House_ ID', 'Area_sqft', 'Bedrooms', 'Bathrooms', 'Age_years',
#        'Location_Score', 'Parking_Spaces', 'Price_lakhs', 'Property_Type',
#        'Furnishing_Status', 'Construction_Status', 'Locality_Type',
#        'Listing_Date', 'Listing_Time'],
#       dtype='object')

# %% [markdown]
# ## 5. Index

# %% [markdown]
# ### Step 1 – Understand the Concept (Markdown)
#
# In my own words: The index identifies each row in a DataFrame. Definition: An index is a label used to identify and access rows.
#
# ### Step 2 – Demonstrate the Concept (Markdown)
#
# By default, Pandas creates: 0, 1, 2
#
# for the three rows.
#
# ### Step 3 – Implement the Concept (Python)
#  Display the DataFrame index

# %%
print(data.index)
# Out:
# RangeIndex(start=0, stop=52, step=1)

# %% [markdown]
# ## 6. head()

# %% [markdown]
# ### Step 1 – Understand the Concept (Markdown)
#
# In my own words: head() displays the first few rows of a DataFrame.
#
# Definition: head() returns the first 5 rows by default.
#
# ### Step 2 – Demonstrate the Concept (Markdown)
#
# Useful when we want to quickly see how the dataset starts.
#
# ### Step 3 – Implement the Concept (Python

# %%
print(data.head())
# Out:
#    House_ ID  Area_sqft  Bedrooms  Bathrooms  Age_years Location_Score  \
# 0          1      850.0       0.0          1       20.5              5
# 1          2      900.0       2.0          1       18.0              5
# 2          3        NaN       2.0          1       15.0              6
# 3          4     1000.9       2.0          2       12.0              6
# 4          5     1050.0       2.0          2       10.0              6
#
#    Parking_Spaces  Price_lakhs      Property_Type Furnishing_Status  \
# 0             1.0           42          Apartment       Unfurnished
# 1             NaN           45  Independent House    Semi-Furnished
# 2             1.0           48              Villa   Fully Furnished
# 3             1.0           52          Apartment    Semi-Furnished
# 4             1.0           55  Independent House       Unfurnished
#
#   Construction_Status Locality_Type Listing_Date Listing_Time
# 0       Ready to Move         Urban     1/5/2024      9:00:00
# ...

# %% [markdown]
# ## 7. tail()

# %% [markdown]
# ### Step 1 – Understand the Concept (Markdown)
#
# In my own words: tail() displays the last few rows of a DataFrame.
#
# Definition: tail() returns the last 5 rows by default.
#
# ### Step 2 – Demonstrate the Concept (Markdown)
#
# Useful for checking the end of a dataset.
#
# ### Step 3 – Implement the Concept (Python)
# Display the last 5 rows

# %%
print(data.tail())
# Out:
#     House_ ID  Area_sqft  Bedrooms  Bathrooms  Age_years Location_Score  \
# 47         48     3400.0       5.0          4        5.0              9
# 48         49     3500.0       5.0          4        3.0             10
# 49         50     3600.0       5.0          4        1.0             10
# 50         51     2750.0       4.0          3       10.0              8
# 51         52     2250.0       4.0          3        8.0              8
#
#     Parking_Spaces  Price_lakhs      Property_Type Furnishing_Status  \
# 47             3.0          305              Villa   Fully Furnished
# 48             3.0          330          Apartment    Semi-Furnished
# 49             3.0          355  Independent House       Unfurnished
# 50             2.0          166          Apartment    Semi-Furnished
# 51             2.0          134          Apartment    Semi-Furnished
#
#    Construction_Status Locality_Type Listing_Date Listing_Time
# ...

# %% [markdown]
# ## 8. sample()

# %% [markdown]
# ### Step 1 – Understand the Concept (Markdown)
#
# In my own words: sample() randomly selects rows from a DataFrame.
#
# Definition: sample() returns randomly selected records from the dataset.
#
# ### Step 2 – Demonstrate the Concept (Markdown)
#
# Instead of always looking at the beginning or end, we can randomly inspect data.
#
# ### Step 3 – Implement the Concept (Python)
#  Select one random row

# %%
print(data.sample(1))
# Out:
#    House_ ID  Area_sqft  Bedrooms  Bathrooms  Age_years Location_Score  \
# 4          5     1050.0       2.0          2       10.0              6
#
#    Parking_Spaces  Price_lakhs      Property_Type Furnishing_Status  \
# 4             1.0           55  Independent House       Unfurnished
#
#   Construction_Status Locality_Type Listing_Date Listing_Time
# 4  Under Construction         Urban    3/17/2024     13:28:00

# %% [markdown]
# ### 9. shape

# %% [markdown]
# ### Step 1 – Understand the Concept (Markdown)
#
# In my own words: shape tells us the number of rows and columns.
#
# Definition: shape returns: (rows, columns)
# ### Step 2 – Demonstrate the Concept (Markdown)
#
# If the output is: (3, 3), it means: 3 rows, 3 columns
#
# ### Step 3 – Implement the Concept (Python)
#  Get rows and columns

# %%
print(data.shape)
# Out:
# (52, 14)

# %% [markdown]
# ## 10. info()

# %% [markdown]
# ### Step 1 – Understand the Concept (Markdown)
#
# In my own words: info() gives a quick summary of the DataFrame.
#
# Definition: info() displays information such as index, columns, data types, and non-null values.
#
# ### Step 2 – Demonstrate the Concept (Markdown)
#
# It is useful for understanding the overall structure of a dataset.
#
# ### Step 3 – Implement the Concept (Python)
# Display DataFrame summary

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   House_ ID            52 non-null     int64
#  1   Area_sqft            51 non-null     float64
#  2   Bedrooms             50 non-null     float64
#  3   Bathrooms            52 non-null     int64
#  4   Age_years            51 non-null     float64
#  5   Location_Score       52 non-null     object
#  6   Parking_Spaces       51 non-null     float64
#  7   Price_lakhs          52 non-null     int64
#  8   Property_Type        52 non-null     object
#  9   Furnishing_Status    52 non-null     object
#  10  Construction_Status  52 non-null     object
#  11  Locality_Type        52 non-null     object
#  12  Listing_Date         52 non-null     object
#  13  Listing_Time         52 non-null     object
# dtypes: float64(4), int64(3), object(7)
# memory usage: 5.8+ KB

# %% [markdown]
# ### 11. describe()

# %% [markdown]
# ### Step 1 – Understand the Concept (Markdown)
#
# In my own words: describe() provides statistical summary information for numerical columns.
#
# Definition: describe() calculates statistics such as count, mean, standard deviation, minimum, and maximum.
#
# Step 2 – Demonstrate the Concept (Markdown)
#
# It helps us quickly understand numerical data.
#
# ### Step 3 – Implement the Concept (Python)
# Generate statistical summary

# %%
print(data.describe())
# Out:
#        House_ ID    Area_sqft   Bedrooms  Bathrooms  Age_years  \
# count  52.000000    51.000000  50.000000  52.000000  51.000000
# mean   26.500000  2134.341176   3.500000   2.634615   6.558824
# std    15.154757   744.236870   0.931315   1.172041   4.299590
# min     1.000000   850.000000   0.000000  -3.000000   1.000000
# 25%    13.750000  1525.000000   3.000000   2.000000   3.500000
# 50%    26.500000  2150.000000   4.000000   3.000000   6.000000
# 75%    39.250000  2725.000000   4.000000   3.000000   8.000000
# max    52.000000  3600.000000   5.000000   4.000000  20.500000
#
#        Parking_Spaces  Price_lakhs
# count       51.000000    52.000000
# mean         1.941176   130.769231
# std          0.580061    92.243840
# min          0.000000  -250.000000
# 25%          2.000000    75.000000
# 50%          2.000000   125.500000
# 75%          2.000000   172.000000
# max          3.000000   355.000000

# %% [markdown]
# ## 12. dtypes

# %% [markdown]
# ### Step 1 – Understand the Concept (Markdown)
#
# In my own words: dtypes shows the data type of every column.
#
# Definition: dtypes returns the data type associated with each DataFrame column.
#
# ### Step 2 – Demonstrate the Concept (Markdown)
#
# For example: Name     object, Age       int64, Marks     int64
# ### Step 3 – Implement the Concept (Python)
#   Check data types of all columns

# %%
print(data.dtypes)
# Out:
# House_ ID                int64
# Area_sqft              float64
# Bedrooms               float64
# Bathrooms                int64
# Age_years              float64
# Location_Score          object
# Parking_Spaces         float64
# Price_lakhs              int64
# Property_Type           object
# Furnishing_Status       object
# Construction_Status     object
# Locality_Type           object
# Listing_Date            object
# Listing_Time            object
# dtype: object

# %% [markdown]
# ## 3. nunique()

# %% [markdown]
# ### Step 1 – Understand the Concept (Markdown)
#
# In my own words: nunique() tells us how many unique values exist in each column.
#
# Definition: nunique() returns the number of distinct values.
#
# ### Step 2 – Demonstrate the Concept (Markdown)
#
# For example:
#
# City = ["Hyderabad", "Hyderabad", "Chennai"]
#
# There are 2 unique cities.
#
# ### Step 3 – Implement the Concept (Python)
#  Count unique values in each column

# %%
print(data.nunique())
# Out:
# House_ ID              52
# Area_sqft              49
# Bedrooms                5
# Bathrooms               6
# Age_years              14
# Location_Score          8
# Parking_Spaces          4
# Price_lakhs            48
# Property_Type           3
# Furnishing_Status       3
# Construction_Status     2
# Locality_Type           2
# Listing_Date           50
# Listing_Time           50
# dtype: int64

# %% [markdown]
# ## 14. value_counts()

# %% [markdown]
# #### Step 1 – Understand the Concept (Markdown)
#
# In my own words: value_counts() counts how many times each unique value occurs.
#
# Definition: value_counts() returns the frequency of each unique value in a Series.
#
# #### Step 2 – Demonstrate the Concept (Markdown)
#
# If:
# City
# Hyderabad
# Hyderabad
# Chennai
#
# then:
#
# Hyderabad → 2
# Chennai   → 1
#
# #### Step 3 – Implement the Concept (Python)

# %%
# Create a categorical column
print(data)
# Count occurrences of each city
print(data["Locality_Type"].value_counts())
# Out:
#     House_ ID  Area_sqft  Bedrooms  Bathrooms  Age_years Location_Score  \
# 0           1      850.0       0.0          1       20.5              5
# 1           2      900.0       2.0          1       18.0              5
# 2           3        NaN       2.0          1       15.0              6
# 3           4     1000.9       2.0          2       12.0              6
# 4           5     1050.0       2.0          2       10.0              6
# 5           6     1100.0       2.0          2        8.0              7
# 6           7     1150.5       NaN          2        7.0           Null
# 7           8     1200.0       3.0          2        6.0              7
# 8           9     1250.0       3.0          2        5.0              8
# 9          10     1300.0       3.0          2        4.0              8
# 10         11     1350.0       3.0          2        NaN              6
# 11         12     1400.0       3.0          2       10.0              7
# ...
